# %% [markdown]
# # Envelope Memory Usage with a Two Fixed Dimensions
#
# This experiment aims to evaluate the memory usage of the envelope seismic attribute operator with two fixed dimensions.
# On this notebook you will find:
# - The problem statement
# - The data collection for the experiment
# - The evaluation of the experiment results.

# %% [markdown]
# ## Problem Statement
#
# The envelope seismic attribute operator is a crucial process in seismic data analysis.
# It enhances seismic data by extracting the envelope of the seismic signal, which is calculated by taking the absolute value of the Hilbert transform of the seismic data.
# This operator is widely used in seismic interpretation, inversion, and attribute analysis.
#
# In this experiment, we aim to evaluate the memory usage of the envelope seismic attribute operator when applied to synthetic seismic data. To achieve this, we will:
#
# 1. Generate synthetic seismic data.
# 2. Apply the envelope operator to the synthetic data using the [DASF](https://github.com/discovery-unicamp/dasf-core) framework.
# 3. Assess the memory usage during this process using [TraceQ](https://github.com/discovery-unicamp/traceq).
#
# Our evaluation will focus on two fixed dimensions (such as inline, crossline, or time).
# This means that we will group the results by two of these dimensions and measure the memory usage for each group, while the third dimension will vary.

# %% [markdown]
# ## Data Collection
#
# In this section, we will outline the steps needed to collect the necessary data for our experiment. The process is organized into the following steps:
#
# 1. **Setup Dependencies:**
#    - Set up the virtual environment running this notebook with the required dependencies.
#
# 2. **Generate Synthetic Seismic Data:**
#    - Generate synthetic seismic data within a specified range of dimensions.
#
# 3. **Execute the Envelope Operator:**
#    - Apply the envelope operator to the synthetic data using the prepared environment and tools.
#
# After completing these steps, we will have the data generated by TraceQ to evaluate the memory usage of the envelope operator.

# %% [markdown]
# ### Setup Dependencies
#
# Before running this step, make sure you are running this notebook in the environment defined by the `.python-version` file.

# %%
# %pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (23.0.1)
# Collecting pip
#   Downloading pip-24.2-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 19.9 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.0.1
#     Uninstalling pip-23.0.1:
#       Successfully uninstalled pip-23.0.1
# Successfully installed pip-24.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# With the base dependencies installed, we now need to install some additional packages from Github.

# %%
# %pip install git+https://github.com/discovery-unicamp/dasf-core.git
# Out:
# Collecting git+https://github.com/discovery-unicamp/dasf-core.git
#   Cloning https://github.com/discovery-unicamp/dasf-core.git to /tmp/pip-req-build-tp5w6u75
#   Running command git clone --filter=blob:none --quiet https://github.com/discovery-unicamp/dasf-core.git /tmp/pip-req-build-tp5w6u75
#   Resolved https://github.com/discovery-unicamp/dasf-core.git to commit fe40cbe5b46f18d26feb0982a47638f4639ac2a8
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting xpysom-dask@ git+https://github.com/jcfaracco/xpysom-dask#egg=master (from dasf==1.0b6)
#   Cloning https://github.com/jcfaracco/xpysom-dask to /tmp/pip-install-lvcdjaag/xpysom-dask_ad15610b99884772a51896a4824d10af
#   Running command git clone --filter=blob:none --quiet https://github.com/jcfaracco/xpysom-dask /tmp/pip-install-lvcdjaag/xpysom-dask_ad15610b99884772a51896a4824d10af
#   Resolved https://github.com/jcfaracco/xpysom-dask to commit c21d10b09f68d89663e2e967bdb5781f76a96b13
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: GPUtil==1.4.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (1.4.0)
# Requirement already satisfied: bokeh==2.4.3 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (2.4.3)
# Requirement already satisfied: charset-normalizer<3.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (2.1.1)
# Requirement already satisfied: dask==2023.3.2 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (2023.3.2)
# Requirement already satisfied: dask_cuda==23.4.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (23.4.0)
# Requirement already satisfied: dask_jobqueue==0.8.2 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (0.8.2)
# Requirement already satisfied: dask_memusage<2.0,>=1.1 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (1.1)
# Requirement already satisfied: dask_ml==2023.3.24 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (2023.3.24)
# Requirement already satisfied: gdown<5.0,>=4.6 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (4.7.3)
# Requirement already satisfied: graphviz==0.20.1 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (0.20.1)
# Requirement already satisfied: h5py==3.10.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (3.10.0)
# Requirement already satisfied: hdbscan==0.8.33 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (0.8.33)
# Requirement already satisfied: ipympl==0.9.3 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (0.9.3)
# Requirement already satisfied: joblib==1.2.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (1.2.0)
# Requirement already satisfied: matplotlib==3.7.1 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (3.7.1)
# Requirement already satisfied: memray==1.10.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (1.10.0)
# Requirement already satisfied: networkx==3.2.1 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (3.2.1)
# Requirement already satisfied: numpy==1.23.5 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (1.23.5)
# Requirement already satisfied: ormsgpack==1.4.1 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (1.4.1)
# Requirement already satisfied: packaging==23.1 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (23.1)
# Requirement already satisfied: pandas==1.5.2 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (1.5.2)
# Requirement already satisfied: portalocker==2.8.2 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (2.8.2)
# Requirement already satisfied: protobuf<=3.20.1 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (3.20.1)
# Requirement already satisfied: psutil==5.9.4 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (5.9.4)
# Requirement already satisfied: pyarrow==10.0.1 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (10.0.1)
# Requirement already satisfied: scikit-learn==1.5.1 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (1.5.1)
# Requirement already satisfied: tornado<7.0,>=6.3 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (6.4.1)
# Requirement already satisfied: xarray==2023.11.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (2023.11.0)
# Requirement already satisfied: xgboost==1.7.5 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (1.7.5)
# Requirement already satisfied: zarr==2.16.1 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (2.16.1)
# Requirement already satisfied: Jinja2>=2.9 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from bokeh==2.4.3->dasf==1.0b6) (3.1.4)
# Requirement already satisfied: pillow>=7.1.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from bokeh==2.4.3->dasf==1.0b6) (10.4.0)
# Requirement already satisfied: PyYAML>=3.10 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from bokeh==2.4.3->dasf==1.0b6) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.10.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from bokeh==2.4.3->dasf==1.0b6) (4.12.2)
# Requirement already satisfied: click>=7.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask==2023.3.2->dasf==1.0b6) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.1.1 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask==2023.3.2->dasf==1.0b6) (3.0.0)
# Requirement already satisfied: fsspec>=0.6.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask==2023.3.2->dasf==1.0b6) (2024.6.1)
# Requirement already satisfied: partd>=1.2.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask==2023.3.2->dasf==1.0b6) (1.4.2)
# Requirement already satisfied: toolz>=0.8.2 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask==2023.3.2->dasf==1.0b6) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask==2023.3.2->dasf==1.0b6) (8.2.0)
# Requirement already satisfied: distributed==2023.3.2.1 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask_cuda==23.4.0->dasf==1.0b6) (2023.3.2.1)
# Requirement already satisfied: pynvml<11.5,>=11.0.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask_cuda==23.4.0->dasf==1.0b6) (11.4.1)
# Requirement already satisfied: numba>=0.54 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask_cuda==23.4.0->dasf==1.0b6) (0.60.0)
# Requirement already satisfied: zict>=0.1.3 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask_cuda==23.4.0->dasf==1.0b6) (3.0.0)
# Requirement already satisfied: scipy in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask_ml==2023.3.24->dasf==1.0b6) (1.14.0)
# Requirement already satisfied: dask-glm>=0.2.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask_ml==2023.3.24->dasf==1.0b6) (0.3.2)
# Requirement already satisfied: multipledispatch>=0.4.9 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask_ml==2023.3.24->dasf==1.0b6) (1.0.0)
# Requirement already satisfied: cython<3,>=0.27 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from hdbscan==0.8.33->dasf==1.0b6) (0.29.37)
# Requirement already satisfied: ipython<9 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipympl==0.9.3->dasf==1.0b6) (8.26.0)
# Requirement already satisfied: ipython-genutils in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipympl==0.9.3->dasf==1.0b6) (0.2.0)
# Requirement already satisfied: traitlets<6 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipympl==0.9.3->dasf==1.0b6) (5.14.3)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipympl==0.9.3->dasf==1.0b6) (8.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from matplotlib==3.7.1->dasf==1.0b6) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from matplotlib==3.7.1->dasf==1.0b6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from matplotlib==3.7.1->dasf==1.0b6) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from matplotlib==3.7.1->dasf==1.0b6) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from matplotlib==3.7.1->dasf==1.0b6) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from matplotlib==3.7.1->dasf==1.0b6) (2.9.0.post0)
# Requirement already satisfied: rich>=11.2.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from memray==1.10.0->dasf==1.0b6) (13.7.1)
# Requirement already satisfied: pytz>=2020.1 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from pandas==1.5.2->dasf==1.0b6) (2024.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from scikit-learn==1.5.1->dasf==1.0b6) (3.5.0)
# Requirement already satisfied: asciitree in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from zarr==2.16.1->dasf==1.0b6) (0.3.3)
# Requirement already satisfied: fasteners in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from zarr==2.16.1->dasf==1.0b6) (0.19)
# Requirement already satisfied: numcodecs>=0.10.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from zarr==2.16.1->dasf==1.0b6) (0.13.0)
# Requirement already satisfied: locket>=1.0.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from distributed==2023.3.2.1->dask_cuda==23.4.0->dasf==1.0b6) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from distributed==2023.3.2.1->dask_cuda==23.4.0->dasf==1.0b6) (1.0.8)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from distributed==2023.3.2.1->dask_cuda==23.4.0->dasf==1.0b6) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from distributed==2023.3.2.1->dask_cuda==23.4.0->dasf==1.0b6) (3.0.0)
# Requirement already satisfied: urllib3>=1.24.3 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from distributed==2023.3.2.1->dask_cuda==23.4.0->dasf==1.0b6) (2.2.2)
# Requirement already satisfied: filelock in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from gdown<5.0,>=4.6->dasf==1.0b6) (3.15.4)
# Requirement already satisfied: requests[socks] in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from gdown<5.0,>=4.6->dasf==1.0b6) (2.32.3)
# Requirement already satisfied: six in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from gdown<5.0,>=4.6->dasf==1.0b6) (1.16.0)
# Requirement already satisfied: tqdm in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from gdown<5.0,>=4.6->dasf==1.0b6) (4.66.5)
# Requirement already satisfied: beautifulsoup4 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from gdown<5.0,>=4.6->dasf==1.0b6) (4.12.3)
# Requirement already satisfied: sparse>=0.7.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask-glm>=0.2.0->dask_ml==2023.3.24->dasf==1.0b6) (0.15.4)
# Requirement already satisfied: zipp>=0.5 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from importlib-metadata>=4.13.0->dask==2023.3.2->dasf==1.0b6) (3.19.2)
# Requirement already satisfied: decorator in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipython<9->ipympl==0.9.3->dasf==1.0b6) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipython<9->ipympl==0.9.3->dasf==1.0b6) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipython<9->ipympl==0.9.3->dasf==1.0b6) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipython<9->ipympl==0.9.3->dasf==1.0b6) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipython<9->ipympl==0.9.3->dasf==1.0b6) (2.18.0)
# Requirement already satisfied: stack-data in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipython<9->ipympl==0.9.3->dasf==1.0b6) (0.6.3)
# Requirement already satisfied: exceptiongroup in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipython<9->ipympl==0.9.3->dasf==1.0b6) (1.2.2)
# Requirement already satisfied: pexpect>4.3 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipython<9->ipympl==0.9.3->dasf==1.0b6) (4.9.0)
# Requirement already satisfied: comm>=0.1.3 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipympl==0.9.3->dasf==1.0b6) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.11 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipympl==0.9.3->dasf==1.0b6) (4.0.11)
# Requirement already satisfied: jupyterlab-widgets~=3.0.11 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipympl==0.9.3->dasf==1.0b6) (3.0.11)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from Jinja2>=2.9->bokeh==2.4.3->dasf==1.0b6) (2.1.5)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from numba>=0.54->dask_cuda==23.4.0->dasf==1.0b6) (0.43.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from rich>=11.2.0->memray==1.10.0->dasf==1.0b6) (3.0.0)
# Requirement already satisfied: soupsieve>1.2 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from beautifulsoup4->gdown<5.0,>=4.6->dasf==1.0b6) (2.5)
# Requirement already satisfied: idna<4,>=2.5 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from requests[socks]->gdown<5.0,>=4.6->dasf==1.0b6) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from requests[socks]->gdown<5.0,>=4.6->dasf==1.0b6) (2024.7.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from requests[socks]->gdown<5.0,>=4.6->dasf==1.0b6) (1.7.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from jedi>=0.16->ipython<9->ipympl==0.9.3->dasf==1.0b6) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=11.2.0->memray==1.10.0->dasf==1.0b6) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from pexpect>4.3->ipython<9->ipympl==0.9.3->dasf==1.0b6) (0.7.0)
# Requirement already satisfied: wcwidth in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython<9->ipympl==0.9.3->dasf==1.0b6) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from stack-data->ipython<9->ipympl==0.9.3->dasf==1.0b6) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from stack-data->ipython<9->ipympl==0.9.3->dasf==1.0b6) (2.4.1)
# Requirement already satisfied: pure-eval in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from stack-data->ipython<9->ipympl==0.9.3->dasf==1.0b6) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Now, we need to install a package that is private.
# In order to do this, you can either use the HTTPS or SSH protocol.
#
# In the next cell you can install with the protocol you prefer, just uncomment the one you want to use.

# %%
# %pip install git+ssh://git@github.com/discovery-unicamp/dasf-seismic.git ### Using SSH
# %pip install git+https://<token>@github.com/discovery-unicamp/dasf-seismic.git ### Using HTTPS -> Don't forget to replate <token> with your own PAT
# Out:
# Collecting git+ssh://****@github.com/discovery-unicamp/dasf-seismic.git
#   Cloning ssh://****@github.com/discovery-unicamp/dasf-seismic.git to /tmp/pip-req-build-r0i6ogqq
#   Running command git clone --filter=blob:none --quiet 'ssh://****@github.com/discovery-unicamp/dasf-seismic.git' /tmp/pip-req-build-r0i6ogqq
#   Resolved ssh://****@github.com/discovery-unicamp/dasf-seismic.git to commit 8037f403f79dd2a628a6d0d14543ead670eb01d4
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main (from dasf-seismic==1.0b5)
#   Cloning https://github.com/discovery-unicamp/dasf-core.git (to revision main) to /tmp/pip-install-9ycaaxxz/dasf_98d02754777143a595027d87f0adf722
#   Running command git clone --filter=blob:none --quiet https://github.com/discovery-unicamp/dasf-core.git /tmp/pip-install-9ycaaxxz/dasf_98d02754777143a595027d87f0adf722
#   Resolved https://github.com/discovery-unicamp/dasf-core.git to commit fe40cbe5b46f18d26feb0982a47638f4639ac2a8
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting glcm-cupy@ git+https://github.com/SerodioJ/glcm-cupy.git@stable (from dasf-seismic==1.0b5)
#   Cloning https://github.com/SerodioJ/glcm-cupy.git (to revision stable) to /tmp/pip-install-9ycaaxxz/glcm-cupy_b105accc2faa401fad9abfad35882d5d
#   Running command git clone --filter=blob:none --quiet https://github.com/SerodioJ/glcm-cupy.git /tmp/pip-install-9ycaaxxz/glcm-cupy_b105accc2faa401fad9abfad35882d5d
#   Running command git checkout -b stable --track origin/stable
#   Switched to a new branch 'stable'
#   branch 'stable' set up to track 'origin/stable'.
#   Resolved https://github.com/SerodioJ/glcm-cupy.git to commit 0c42b921002612712c3f830644bfc0fd9725484c
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting multidimio==0.4.2 (from dasf-seismic==1.0b5)
#   Downloading multidimio-0.4.2-py3-none-any.whl.metadata (7.7 kB)
# Collecting scikit-image==0.22.0 (from dasf-seismic==1.0b5)
#   Downloading scikit_image-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting segyio==1.9.12 (from dasf-seismic==1.0b5)
#   Downloading segyio-1.9.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.8 kB)
# Collecting segysak==0.4 (from dasf-seismic==1.0b5)
#   Downloading segysak-0.4-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from multidimio==0.4.2->dasf-seismic==1.0b5) (8.1.7)
# Collecting click-params<0.5.0,>=0.4.0 (from multidimio==0.4.2->dasf-seismic==1.0b5)
#   Downloading click_params-0.4.1-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: dask>=2022.11.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from multidimio==0.4.2->dasf-seismic==1.0b5) (2023.3.2)
# Requirement already satisfied: numba<1.0.0,>=0.55.2 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from multidimio==0.4.2->dasf-seismic==1.0b5) (0.60.0)
# Requirement already satisfied: psutil<6.0.0,>=5.9.1 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from multidimio==0.4.2->dasf-seismic==1.0b5) (5.9.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.64.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from multidimio==0.4.2->dasf-seismic==1.0b5) (4.66.5)
# Requirement already satisfied: zarr<3.0.0,>=2.12.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from multidimio==0.4.2->dasf-seismic==1.0b5) (2.16.1)
# Requirement already satisfied: numpy>=1.22 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from scikit-image==0.22.0->dasf-seismic==1.0b5) (1.23.5)
# Requirement already satisfied: scipy>=1.8 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from scikit-image==0.22.0->dasf-seismic==1.0b5) (1.14.0)
# Requirement already satisfied: networkx>=2.8 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from scikit-image==0.22.0->dasf-seismic==1.0b5) (3.2.1)
# Requirement already satisfied: pillow>=9.0.1 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from scikit-image==0.22.0->dasf-seismic==1.0b5) (10.4.0)
# Collecting imageio>=2.27 (from scikit-image==0.22.0->dasf-seismic==1.0b5)
#   Downloading imageio-2.34.2-py3-none-any.whl.metadata (4.9 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image==0.22.0->dasf-seismic==1.0b5)
#   Downloading tifffile-2024.7.24-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: packaging>=21 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from scikit-image==0.22.0->dasf-seismic==1.0b5) (23.1)
# Collecting lazy_loader>=0.3 (from scikit-image==0.22.0->dasf-seismic==1.0b5)
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: pandas in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from segysak==0.4->dasf-seismic==1.0b5) (1.5.2)
# Requirement already satisfied: matplotlib in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from segysak==0.4->dasf-seismic==1.0b5) (3.7.1)
# Requirement already satisfied: xarray in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from segysak==0.4->dasf-seismic==1.0b5) (2023.11.0)
# Requirement already satisfied: distributed in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from segysak==0.4->dasf-seismic==1.0b5) (2023.3.2.1)
# Collecting pyzgy (from segysak==0.4->dasf-seismic==1.0b5)
#   Downloading pyzgy-0.0.9-py3-none-any.whl.metadata (377 bytes)
# Collecting h5netcdf (from segysak==0.4->dasf-seismic==1.0b5)
#   Downloading h5netcdf-1.3.0-py3-none-any.whl.metadata (13 kB)
# Collecting addict (from segysak==0.4->dasf-seismic==1.0b5)
#   Downloading addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Collecting more-itertools>=8.0 (from segysak==0.4->dasf-seismic==1.0b5)
#   Downloading more_itertools-10.4.0-py3-none-any.whl.metadata (36 kB)
# Collecting setuptools-scm (from segysak==0.4->dasf-seismic==1.0b5)
#   Downloading setuptools_scm-8.1.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting xpysom-dask@ git+https://github.com/jcfaracco/xpysom-dask#egg=master (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5)
#   Cloning https://github.com/jcfaracco/xpysom-dask to /tmp/pip-install-9ycaaxxz/xpysom-dask_3d62c0fcfa274c02803ff04fa1d65931
#   Running command git clone --filter=blob:none --quiet https://github.com/jcfaracco/xpysom-dask /tmp/pip-install-9ycaaxxz/xpysom-dask_3d62c0fcfa274c02803ff04fa1d65931
#   Resolved https://github.com/jcfaracco/xpysom-dask to commit c21d10b09f68d89663e2e967bdb5781f76a96b13
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: GPUtil==1.4.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (1.4.0)
# Requirement already satisfied: bokeh==2.4.3 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (2.4.3)
# Requirement already satisfied: charset-normalizer<3.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (2.1.1)
# Requirement already satisfied: dask_cuda==23.4.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (23.4.0)
# Requirement already satisfied: dask_jobqueue==0.8.2 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (0.8.2)
# Requirement already satisfied: dask_memusage<2.0,>=1.1 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (1.1)
# Requirement already satisfied: dask_ml==2023.3.24 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (2023.3.24)
# Requirement already satisfied: gdown<5.0,>=4.6 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (4.7.3)
# Requirement already satisfied: graphviz==0.20.1 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (0.20.1)
# Requirement already satisfied: h5py==3.10.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (3.10.0)
# Requirement already satisfied: hdbscan==0.8.33 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (0.8.33)
# Requirement already satisfied: ipympl==0.9.3 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (0.9.3)
# Requirement already satisfied: joblib==1.2.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (1.2.0)
# Requirement already satisfied: memray==1.10.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (1.10.0)
# Requirement already satisfied: ormsgpack==1.4.1 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (1.4.1)
# Requirement already satisfied: portalocker==2.8.2 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (2.8.2)
# Requirement already satisfied: protobuf<=3.20.1 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (3.20.1)
# Requirement already satisfied: pyarrow==10.0.1 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (10.0.1)
# Requirement already satisfied: scikit-learn==1.5.1 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (1.5.1)
# Requirement already satisfied: tornado<7.0,>=6.3 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (6.4.1)
# Requirement already satisfied: xgboost==1.7.5 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (1.7.5)
# Requirement already satisfied: Jinja2>=2.9 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from bokeh==2.4.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (3.1.4)
# Requirement already satisfied: PyYAML>=3.10 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from bokeh==2.4.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.10.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from bokeh==2.4.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (4.12.2)
# Requirement already satisfied: cloudpickle>=1.1.1 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask>=2022.11.0->multidimio==0.4.2->dasf-seismic==1.0b5) (3.0.0)
# Requirement already satisfied: fsspec>=0.6.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask>=2022.11.0->multidimio==0.4.2->dasf-seismic==1.0b5) (2024.6.1)
# Requirement already satisfied: partd>=1.2.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask>=2022.11.0->multidimio==0.4.2->dasf-seismic==1.0b5) (1.4.2)
# Requirement already satisfied: toolz>=0.8.2 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask>=2022.11.0->multidimio==0.4.2->dasf-seismic==1.0b5) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask>=2022.11.0->multidimio==0.4.2->dasf-seismic==1.0b5) (8.2.0)
# Requirement already satisfied: pynvml<11.5,>=11.0.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask_cuda==23.4.0->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (11.4.1)
# Requirement already satisfied: zict>=0.1.3 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask_cuda==23.4.0->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (3.0.0)
# Requirement already satisfied: dask-glm>=0.2.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask_ml==2023.3.24->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (0.3.2)
# Requirement already satisfied: multipledispatch>=0.4.9 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask_ml==2023.3.24->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (1.0.0)
# Requirement already satisfied: locket>=1.0.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from distributed->segysak==0.4->dasf-seismic==1.0b5) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from distributed->segysak==0.4->dasf-seismic==1.0b5) (1.0.8)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from distributed->segysak==0.4->dasf-seismic==1.0b5) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from distributed->segysak==0.4->dasf-seismic==1.0b5) (3.0.0)
# Requirement already satisfied: urllib3>=1.24.3 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from distributed->segysak==0.4->dasf-seismic==1.0b5) (2.2.2)
# Requirement already satisfied: cython<3,>=0.27 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from hdbscan==0.8.33->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (0.29.37)
# Requirement already satisfied: ipython<9 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (8.26.0)
# Requirement already satisfied: ipython-genutils in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (0.2.0)
# Requirement already satisfied: traitlets<6 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (5.14.3)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (8.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from matplotlib->segysak==0.4->dasf-seismic==1.0b5) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from matplotlib->segysak==0.4->dasf-seismic==1.0b5) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from matplotlib->segysak==0.4->dasf-seismic==1.0b5) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from matplotlib->segysak==0.4->dasf-seismic==1.0b5) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from matplotlib->segysak==0.4->dasf-seismic==1.0b5) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from matplotlib->segysak==0.4->dasf-seismic==1.0b5) (2.9.0.post0)
# Requirement already satisfied: rich>=11.2.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from memray==1.10.0->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (13.7.1)
# Requirement already satisfied: pytz>=2020.1 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from pandas->segysak==0.4->dasf-seismic==1.0b5) (2024.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from scikit-learn==1.5.1->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (3.5.0)
# Requirement already satisfied: asciitree in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from zarr<3.0.0,>=2.12.0->multidimio==0.4.2->dasf-seismic==1.0b5) (0.3.3)
# Requirement already satisfied: fasteners in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from zarr<3.0.0,>=2.12.0->multidimio==0.4.2->dasf-seismic==1.0b5) (0.19)
# Requirement already satisfied: numcodecs>=0.10.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from zarr<3.0.0,>=2.12.0->multidimio==0.4.2->dasf-seismic==1.0b5) (0.13.0)
# Collecting validators<0.21,>=0.20 (from click-params<0.5.0,>=0.4.0->multidimio==0.4.2->dasf-seismic==1.0b5)
#   Downloading validators-0.20.0.tar.gz (30 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from gdown<5.0,>=4.6->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (3.15.4)
# Requirement already satisfied: requests[socks] in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from gdown<5.0,>=4.6->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (2.32.3)
# Requirement already satisfied: six in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from gdown<5.0,>=4.6->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from gdown<5.0,>=4.6->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (4.12.3)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from numba<1.0.0,>=0.55.2->multidimio==0.4.2->dasf-seismic==1.0b5) (0.43.0)
# Requirement already satisfied: setuptools in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from setuptools-scm->segysak==0.4->dasf-seismic==1.0b5) (65.5.0)
# Collecting tomli>=1 (from setuptools-scm->segysak==0.4->dasf-seismic==1.0b5)
#   Using cached tomli-2.0.1-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: sparse>=0.7.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask-glm>=0.2.0->dask_ml==2023.3.24->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (0.15.4)
# Requirement already satisfied: zipp>=0.5 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from importlib-metadata>=4.13.0->dask>=2022.11.0->multidimio==0.4.2->dasf-seismic==1.0b5) (3.19.2)
# Requirement already satisfied: decorator in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipython<9->ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipython<9->ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipython<9->ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipython<9->ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipython<9->ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (2.18.0)
# Requirement already satisfied: stack-data in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipython<9->ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (0.6.3)
# Requirement already satisfied: exceptiongroup in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipython<9->ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (1.2.2)
# Requirement already satisfied: pexpect>4.3 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipython<9->ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (4.9.0)
# Requirement already satisfied: comm>=0.1.3 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.11 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (4.0.11)
# Requirement already satisfied: jupyterlab-widgets~=3.0.11 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (3.0.11)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from Jinja2>=2.9->bokeh==2.4.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from rich>=11.2.0->memray==1.10.0->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (3.0.0)
# Requirement already satisfied: soupsieve>1.2 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from beautifulsoup4->gdown<5.0,>=4.6->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (2.5)
# Requirement already satisfied: idna<4,>=2.5 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from requests[socks]->gdown<5.0,>=4.6->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from requests[socks]->gdown<5.0,>=4.6->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (2024.7.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from requests[socks]->gdown<5.0,>=4.6->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (1.7.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from jedi>=0.16->ipython<9->ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=11.2.0->memray==1.10.0->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from pexpect>4.3->ipython<9->ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (0.7.0)
# Requirement already satisfied: wcwidth in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython<9->ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from stack-data->ipython<9->ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from stack-data->ipython<9->ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (2.4.1)
# Requirement already satisfied: pure-eval in /home/delucca/.pyenv/versions/3.10.13/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from stack-data->ipython<9->ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (0.2.3)
# Downloading multidimio-0.4.2-py3-none-any.whl (67 kB)
# Downloading scikit_image-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 25.7 MB/s eta 0:00:00a 0:00:01
# Downloading segyio-1.9.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (85 kB)
# Downloading segysak-0.4-py3-none-any.whl (313 kB)
# Downloading click_params-0.4.1-py3-none-any.whl (12 kB)
# Downloading imageio-2.34.2-py3-none-any.whl (313 kB)
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading more_itertools-10.4.0-py3-none-any.whl (60 kB)
# Downloading tifffile-2024.7.24-py3-none-any.whl (226 kB)
# Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Downloading h5netcdf-1.3.0-py3-none-any.whl (43 kB)
# Downloading pyzgy-0.0.9-py3-none-any.whl (123 kB)
# Downloading setuptools_scm-8.1.0-py3-none-any.whl (43 kB)
# Using cached tomli-2.0.1-py3-none-any.whl (12 kB)
# Building wheels for collected packages: dasf-seismic, glcm-cupy, validators
#   Building wheel for dasf-seismic (pyproject.toml) ... done
#   Created wheel for dasf-seismic: filename=dasf_seismic-1.0b5-py3-none-any.whl size=49719 sha256=30c673ca31449c21660f7f727467f8268d9d9f5294b4b7bdce3574aa6290befd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-zifbl3yf/wheels/98/52/a0/b54bba6a18659e294b618ff8497d26afae8cf552ae13d17d11
#   Building wheel for glcm-cupy (pyproject.toml) ... done
#   Created wheel for glcm-cupy: filename=glcm_cupy-0.2.1-py3-none-any.whl size=19719 sha256=607e617e573802fea72bdba79c370f6bbb2c68f1b6a3c19ff29c5e98de0aebc7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-zifbl3yf/wheels/68/7b/b9/bcc08d667e404e77ce47e3b26d4f5c269f8fcdb11aa5391ac3
#   Building wheel for validators (pyproject.toml) ... done
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19574 sha256=f491a7d9724b59f9d05008f9cbe445aba56190c35b7f155056f32f3b8cc5bc41
#   Stored in directory: /home/delucca/.cache/pip/wheels/f2/ed/dd/d3a556ad245ef9dc570c6bcd2f22886d17b0b408dd3bbb9ac3
# Successfully built dasf-seismic glcm-cupy validators
# Installing collected packages: addict, validators, tomli, tifffile, segyio, more-itertools, lazy_loader, imageio, setuptools-scm, scikit-image, pyzgy, h5netcdf, click-params, multidimio, glcm-cupy, segysak, dasf-seismic
# Successfully installed addict-2.4.0 click-params-0.4.1 dasf-seismic-1.0b5 glcm-cupy-0.2.1 h5netcdf-1.3.0 imageio-2.34.2 lazy_loader-0.4 more-itertools-10.4.0 multidimio-0.4.2 pyzgy-0.0.9 scikit-image-0.22.0 segyio-1.9.12 segysak-0.4 setuptools-scm-8.1.0 tifffile-2024.7.24 tomli-2.0.1 validators-0.20.0
# Note: you may need to restart the kernel to use updated packages.
